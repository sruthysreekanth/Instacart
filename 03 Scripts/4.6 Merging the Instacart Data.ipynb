# %% [markdown]
# # importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\sruth\OneDrive\Desktop\Career Foundry\Data Immersion\A4-Python fundamentals for data analyst\4.6 Combining & Exporting Data\04-2023 Instacart Basket Analysis\02 Data'

# %%
df_ords_prior=pd.read_csv(os.path.join(path,'Original data','order_products_prior.csv'))

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_prior.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
df_ords=pd.read_csv(os.path.join(path,'prepared data','orders_checked.csv'))

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_previous_order
# 0                        8                        NaN
# 1                        7                       15.0
# 2                       12                       21.0
# ...

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 6)

# %%
df_merged=df_ords.merge(df_ords_prior,on='order_id',indicator=True)

# %%
df_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_previous_order  product_id  \
# 0                         8                        NaN         196
# 1                         8                        NaN       14084
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.shape
# Out:
# (32434489, 10)

# %% [markdown]
# # Export data in pickle format .pkl

# %%
df_merged.to_pickle(os.path.join(path,'prepared data','orders_products_combined.pkl'))
